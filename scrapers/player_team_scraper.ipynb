# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up Selenium
options = Options()
options.add_argument("--headless=new")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("user-agent=Mozilla/5.0")

driver = webdriver.Chrome(options=options)

# Go to the page
url = "https://www.baseball-reference.com/leagues/majors/2025-standard-batting.shtml"
driver.get(url)

# Wait longer to make sure JS finishes loading
time.sleep(5)

# Parse page
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# ✅ Now the table is directly in the page, not hidden in a comment
table = soup.find('table', {'id': 'players_standard_batting'})

# Check if we found it
if table is None:
    print("❌ Table not found after JS load")
    driver.quit()
    raise ValueError("Table still not found after waiting.")

# Read table into pandas
df = pd.read_html(str(table))[0]

# Clean up repeated headers
df = df[df['Rk'] != 'Rk'].reset_index(drop=True)

print("✅ DataFrame preview:")
print(df.head())

driver.quit()
# Out:
# C:\Users\Joshua\AppData\Local\Temp\ipykernel_9192\3280241530.py:37: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# ✅ DataFrame preview:
#   Rk           Player Age Team  Lg  WAR   G   PA   AB   R  ...  rOBA Rbat+  \
# 0  1        Ian Happ#  30  CHC  NL  1.1  36  173  150  29  ...  .355   128
# 1  2    Jarren Duran*  28  BOS  AL  0.5  35  168  155  19  ...  .335   106
# 2  3     Kyle Tucker*  28  CHC  NL  1.5  36  168  141  30  ...  .418   163
# 3  4  Corbin Carroll*  24  ARI  NL  1.4  35  165  150  28  ...  .404   155
# 4  5   Rafael Devers*  28  BOS  AL  0.8  36  165  136  22  ...  .365   133
#
#    TB GIDP HBP SH SF IBB    Pos Awards
# 0  61    3   0  0  2   0     *7    NaN
# 1  65    1   2  0  1   0  *7/89    NaN
# 2  79    3   0  0  1   3   *9/D    NaN
# 3  89    1   4  0  0   1   *9/H    NaN
# 4  60    2   1  0  2   2     *D    NaN
#
# [5 rows x 34 columns]

# %%
import unicodedata

# %%
df2=df[['Player','Team']]

# %%
multi_team_flags = ['2TM', '3TM', '4TM', '5TM']
filtered_df = df2[~df2['team'].isin(multi_team_flags)].copy()


# Step 2: Keep only the LAST team listed for each player (i.e., current team)
df2 = filtered_df.drop_duplicates(subset='player', keep='last').reset_index(drop=True)

# %%
def clean_name_symbols(name):
    if not isinstance(name, str):
        return name
    return name.replace('*', '').replace('#', '')
df2['Player'] = df2['Player'].apply(clean_name_symbols)

# %%
#normalizing the names, getting rid of accents
def normalize_name(name):
    if not isinstance(name, str):
        return name
    return unicodedata.normalize('NFKD', name).encode('ascii', 'ignore').decode('utf-8')
df2['Player'] = df2['Player'].apply(normalize_name)

# %%
df2['Player'].unique()
# Out:
# array(['Ian Happ', 'Jarren Duran', 'Kyle Tucker', 'Corbin Carroll',
#        'Rafael Devers', 'Lars Nootbaar', 'Francisco Lindor',
#        'Pete Alonso', 'Juan Soto', 'Alex Bregman', 'Bryan Reynolds',
#        'Brent Rooker', 'Willy Adames', 'Xavier Edwards',
#        'Jackson Chourio', 'Elly De La Cruz', 'Aaron Judge',
#        'Bobby Witt Jr.', 'Geraldo Perdomo', 'Julio Rodriguez',
#        'Bo Bichette', 'James Wood', 'Bryce Harper', 'Shohei Ohtani',
#        'Cal Raleigh', 'Dansby Swanson', 'Yandy Diaz', 'TJ Friedl',
#        'Lawrence Butler', 'Matt Chapman', 'Willson Contreras',
#        'Kyle Schwarber', 'Tyler Soderstrom', 'Pete Crow-Armstrong',
#        'Austin Riley', 'Heliot Ramos', 'Spencer Torkelson',
#        'Vladimir Guerrero Jr.', 'Matt Olson', 'Ozzie Albies',
#        'Steven Kwan', 'Josh Naylor', 'Vinnie Pasquantino',
#        'Brendan Donovan', 'Paul Goldschmidt', 'Anthony Santander',
#        'Brice Turang', 'Jose Altuve', 'JJ Bleday', 'Jung Hoo Lee',
#        'Nathaniel Lowe', 'Christian Yelich', 'William Contreras',
#        'Riley Greene', 'Seiya Suzuki', 'Oneil Cruz', 'Jonathan India',
#        'Brandon Nimmo', 'Isaac Paredes', 'Trevor Story', 'Trea Turner',
#        'Nolan Arenado', 'Randy Arozarena', 'Mookie Betts', 'Jeremy Pena',
#        'Eugenio Suarez', 'Fernando Tatis Jr.', 'Anthony Volpe',
#        'Ty France', 'Trevor Larnach', 'Jacob Wilson', 'Michael Harris II',
#        'Manny Machado', 'Luis Robert Jr.', 'Mark Vientos',
#        'Nick Castellanos', 'Marcus Semien', 'Miguel Vargas',
#        'Nico Hoerner', 'Andrew Vaughn', 'Xander Bogaerts', 'Byron Buxton',
#        'Maikel Garcia', 'Andres Gimenez', "Ke'Bryan Hayes",
#        'Teoscar Hernandez', 'Ryan McMahon', 'Marcell Ozuna',
#        'Christian Walker', 'Alec Bohm', 'Sal Frelick', 'Salvador Perez',
#        'J.P. Crawford', 'Lourdes Gurriel Jr.', 'Carlos Correa',
#        'Wilmer Flores', 'Carlos Santana', 'Taylor Ward', 'Wilyer Abreu',
#        'Michael Busch', 'Junior Caminero', 'Cedric Mullins', 'Joey Ortiz',
#        'Jose Ramirez', 'Cody Bellinger', 'Jorge Soler', 'Adolis Garcia',
#        'Gavin Lux', 'Bryson Stott', 'Shea Langeliers', 'Zach McKinstry',
#        'Kyle Stowers', 'Brandon Lowe', 'Adley Rutschman',
#        'Kristian Campbell', 'Michael Toglia', 'Hunter Goodman',
#        'Kyle Manzardo', 'Max Muncy', 'Lenyn Sosa', 'Jazz Chisholm Jr.',
#        'Dylan Crews', 'Michael Massey', 'Nolan Schanuel',
#        'Luis Garcia Jr.', 'Andy Pages', 'Mike Yastrzemski',
#        'Michael Conforto', 'Ben Rice', 'Keibert Ruiz', 'Victor Scott II',
#        'Luis Arraez', 'Tommy Edman', 'Rhys Hoskins', 'Spencer Steer',
#        'Yordan Alvarez', 'Josh Bell', 'Max Kepler', 'Mike Trout',
#        'Eric Wagaman', 'Trey Sweeney', 'Otto Lopez', 'J.T. Realmuto',
#        'Luis Rengifo', 'Kerry Carpenter', 'Matt McLain', 'Austin Wells',
#        'Jonathan Aranda', 'Ceddanne Rafaela', 'George Springer',
#        'Jordan Walker', 'Gabriel Arias', 'Andrew McCutchen', 'Tommy Pham',
#        'Triston Casas', 'Yainer Diaz', 'Adam Frazier', 'Jasson Dominguez',
#        'Ryan Mountcastle', 'Gunnar Henderson', 'Alec Burleson',
#        'Isiah Kiner-Falefa', 'Jake Burger', 'Will Smith',
#        'LaMonte Wade Jr.', 'Joey Bart', 'Brenton Doyle', 'Harrison Bader',
#        'Alejandro Kirk', 'Wyatt Langford', 'Brooks Baldwin',
#        'Edouard Julien', "Logan O'Hoppe", 'Pavin Smith', 'Colt Keith',
#        'Jake Meyers', 'Ryan Jeffers', 'Christopher Morel', 'Josh Smith',
#        'Patrick Bailey', 'Kyle Farmer', 'Kameron Misner', 'Javier Baez',
#        'Josh Jung', 'Gavin Sheets', 'Tyrone Taylor', 'Freddie Freeman',
#        'Jonah Heim', 'Jordan Westburg', 'CJ Abrams', 'Miguel Andujar',
#        'Oswaldo Cabrera', 'Jackson Holliday', 'Gabriel Moreno',
#        'Alek Thomas', 'Gleyber Torres', 'Enmanuel Valdez', 'Jo Adell',
#        'Mickey Moniak', 'Kyren Paris', 'Jacob Young', 'Andrew Benintendi',
#        'Trent Grisham', "Ryan O'Hearn", 'Joc Pederson', 'Gio Urshela',
#        'Luisangel Acuna', 'Dillon Dingler', 'Masyn Winn', 'Matt Mervis',
#        'Brayan Rocchio', 'Corey Seager', 'Cam Smith', 'Jose Iglesias',
#        'Pedro Pages', 'Jorge Polanco', 'Nick Allen', 'Jeimer Candelario',
#        'Kyle Isbel', 'Tyler Fitzgerald', 'Jake Fraley', 'Nolan Jones',
#        'Carlos Narvaez', 'Taylor Walls', 'Santiago Espinal',
#        'Heston Kjerstad', 'Bo Naylor', 'Ernie Clement', 'Luke Raley',
#        'Alan Roden', 'Danny Jansen', 'Sean Murphy', 'Hunter Renfroe',
#        'Jose Trevino', 'Jordan Beck', 'Leody Taveras', 'Ramon Urias',
#        'Carson Kelly', 'Alex Call', 'Luis Urias', 'Drew Waters',
#        'Jose Caballero', 'Garrett Mitchell', 'Dylan Moore',
#        'Rowdy Tellez', 'Jesse Winker', 'Nolan Gorman',
#        'Justyn-Henry Malloy', 'Kike Hernandez', 'Tim Tawa',
#        'Nick Martini', "Tyler O'Neill", 'Luis Torrens', 'Elias Diaz',
#        'Liam Hicks', 'Jake Mangum', 'Noelvi Marte', 'Dane Myers',
#        'Brendan Rodgers', 'Miguel Amaya', 'Willi Castro',
#        'Michael A. Taylor', 'Griffin Conine', 'Starling Marte',
#        'Angel Martinez', 'Johan Rojas', 'Matt Thaiss', 'Blake Dunn',
#        'Miles Mastrobuoni', 'Jhonkensy Noel', 'Javier Sanoja',
#        'Daniel Schneemann', 'Ezequiel Tovar', 'Ben Williamson',
#        'Jonah Bride', 'Brooks Lee', 'Graham Pauley', 'Matt Shaw',
#        'Will Wagner', 'Matt Wallner', 'Mitch Garver', 'Freddy Fermin',
#        'Jarred Kelenic', 'Alex Verdugo', 'Tim Anderson', 'Amed Rosario',
#        'Jesus Sanchez', 'Jason Heyward', 'Jacob Stallings', 'Eli White',
#        'Connor Norby', 'Drake Baldwin', 'Caleb Durbin', 'Kyle Higashioka',
#        'Nick Maton', 'Zach Neto', 'Jon Berti',
#        'Christian Encarnacion-Strand', 'Edgar Quero', 'Jared Triolo',
#        'Jacob Amaya', 'Sean Bouchard', 'Ramon Laureano', 'Brett Baty',
#        'Austin Hays', 'Joshua Palacios', 'Chandler Simpson',
#        'Justin Turner', 'Cavan Biggio', 'Paul DeJong', 'Andy Ibanez',
#        'Myles Straw', 'Tyler Wade', 'Isaac Collins', 'Oscar Gonzalez',
#        'Vinny Capra', 'Romy Gonzalez', 'Randal Grichuk', 'Nathan Lukes',
#        'Brandon Marsh', 'Curtis Mead', 'Christian Vazquez',
#        'Mauricio Dubon', 'Jose Tena', 'Zach Dezenzo', 'Luis Matos',
#        'Chase Meidroth', 'Donovan Solano', 'MJ Melendez', 'Jake Bauers',
#        'Martin Maldonado', 'Leo Rivas', 'Victor Caratini',
#        'Bryan De La Cruz', 'Endy Rodriguez', 'Miguel Rojas', 'Derek Hill',
#        'Lane Thomas', 'David Hamilton', 'Brandon Lockridge',
#        'Jake McCarthy', 'Agustin Ramirez', 'Victor Robles',
#        "Travis d'Arnaud", 'Nick Kurtz', 'Ben Rortvedt', 'Edmundo Sosa',
#        'Jack Suwinski', 'Jake Cronenworth', 'Ryan Kreidler',
#        'Ketel Marte', 'Thomas Saggese', 'Adael Amador', 'Jose Herrera',
#        'Oswald Peraza', 'Seth Brown', 'Alexander Canario', 'Kris Bryant',
#        'Oliver Dunn', 'Jackson Merrill', 'Luken Baker', 'Yuli Gurriel',
#        'Christian Koss', 'Rob Refsnyder', 'Addison Barger', 'Ryan Bliss',
#        'Mickey Gasper', 'Mark Canha', 'Garrett Hampson', 'Austin Hedges',
#        'Kevin Pillar', 'Austin Barnes', 'Jace Jung', 'Zac Veen',
#        'Francisco Alvarez', 'Jose Miranda', 'Yohel Pozo', 'Austin Wynns',
#        'Gary Sanchez', 'J.C. Escarra', 'Dustin Harris', 'Tyler Heineman',
#        'Sam Huff', 'Connor Wong', 'Jeff McNeil', 'Nasim Nunez',
#        'Chas McCormick', 'Kevin Newman', 'Max Schuemann', 'Orlando Arcia',
#        'Henry Davis', 'Travis Jankowski', 'DaShawn Keirsey Jr.',
#        'Hayden Senger', 'Jorge Mateo', 'Nick Fortes', 'Yoan Moncada',
#        'Tomas Nido', 'Luke Keaschall', 'Jhonny Pereda', 'Jonny DeLuca',
#        'Eric Haase', 'Ivan Herrera', 'Rafael Marchan', 'Casey Schmitt',
#        'Jose Siri', 'Ronny Simon', 'Chris Taylor', 'Alan Trejo',
#        'Riley Adams', 'Jake Rogers', 'Bobby Dalbec', 'Pablo Reyes',
#        'Davis Schneider', 'Aaron Schunk', 'Stuart Fairchild',
#        'Manuel Margot', 'Austin Slater', 'Kody Clemens', 'Will Wilson',
#        'Colton Cowser', 'Blake Sabol', 'Nicky Lopez', 'Jose Azocar',
#        'Korey Lee', 'Michael Siani', 'Daulton Varsho', 'Gage Workman',
#        'Jorge Barrosa', 'Tyler Freeman', 'Matt Gorski', 'Tirso Ornelas',
#        'Jurickson Profar', 'Ezequiel Duran', 'Tyler Stephenson',
#        'David Villar', 'Jose Barrero', 'Dylan Carlson', 'Mike Tauchman',
#        'Nick Ahmed', 'Gustavo Campero', 'Luis Campusano',
#        'Jacob Hurtubise', 'Connor Joe', 'Coco Montes', 'Omar Narvaez',
#        'Rhylan Thomas', 'Jorbit Vivas', 'Vidal Brujan', 'J.D. Davis',
#        'Emmanuel Rivera', 'Samad Taylor', 'Weston Wilson',
#        'Braxton Fulford', 'Cal Stevenson', 'Rob Brantly', 'Daz Cameron',
#        'Tsung-Che Cheng', 'Blaine Crim', 'Owen Miller', 'Eddie Rosario',
#        'Tyler Callihan', 'Coby Mayo', 'Jonathan Ornelas',
#        'Chadwick Tromp', 'Maverick Handley', 'Mason McCoy',
#        'Johnathan Rodriguez', 'Tyler Tolbert', 'Ji Hwan Bae',
#        'Tucker Barnhart', 'Will Benson', 'Jonatan Clase', 'Hyeseong Kim',
#        'Trey Lipscomb', 'Luke Maile', 'Richie Palacios', 'Brett Wisely',
#        'Dominic Canzone', 'Hunter Feduccia', 'Nick Gonzales',
#        'Josh Rojas', 'Greg Jones', 'Josh Lowe', 'Dairon Blanco',
#        'Niko Kavadas', 'Ryne Nelson', 'Colin Rea', 'Abraham Toro',
#        'Jake Bird', 'Matt Bowman', 'Angel Chivilli', 'Emmanuel Clase',
#        'Jhoan Duran', 'Ryan Helsley', 'Jeff Hoffman', 'Drey Jameson',
#        'Tommy Kahnle', 'Casey Legumina', 'Joe Mantiply',
#        'Justin Martinez', 'Phil Maton', 'Tyler Matzek', 'Juan Mejia',
#        'Shelby Miller', 'Hoby Milner', 'Tyler Owens', 'Andre Pallante',
#        'A.J. Puk', 'Nick Sandlin', 'Tanner Scott', 'Ryan Thompson',
#        'MLB Average'], dtype=object)

# %%
df2.to_csv('../batter_record_1_hit/stats/batter_team_2025.csv')
